# %%
from pyspark import SparkConf
from pyspark.sql import SparkSession

# %%
conf = (SparkConf()
            .setMaster("yarn")
            .set("spark.executor.cores", 5)
            .set("spark.sql.shuffle.partitions", 200)
            .set("spark.default.parallelism", 200)
            .set("spark.executor.memory", "7g")
            .set("spark.dynamicAllocation.maxExecutors", 20)
        )

spark = SparkSession \
    .builder \
    .config(conf=conf) \
    .appName("Test_PySpark") \
    .getOrCreate()
# Out:
# ---------------------------------------------------------------------------
# PySparkRuntimeError                       Traceback (most recent call last)
# Cell In[4], line 14
#       1 conf = (SparkConf()
#       2             .setMaster("yarn")
#       3             .set("spark.executor.cores", 5)
#    (...)      7             .set("spark.dynamicAllocation.maxExecutors", 20)
#       8         )
#      10 spark = SparkSession \
#      11     .builder \
#      12     .config(conf=conf) \
#      13     .appName("Test_PySpark") \
# ---> 14     .getOrCreate()
#
# File c:\Users\ferch\OneDrive\Escritorio\ICAI\QUINTO\2_BIGDATA\PROYECTO\XRP\Lib\site-packages\pyspark\sql\session.py:557, in SparkSession.Builder.getOrCreate(self)
#     555     sparkConf.set(key, value)
#     556 # This SparkContext may be an existing one.
# --> 557 sc = SparkContext.getOrCreate(sparkConf)
#     558 # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     559 # by all sessions.
#     560 session = SparkSession(sc, options=self._options)
#
# File c:\Users\ferch\OneDrive\Escritorio\ICAI\QUINTO\2_BIGDATA\PROYECTO\XRP\Lib\site-packages\pyspark\core\context.py:542, in SparkContext.getOrCreate(cls, conf)
#     540 with SparkContext._lock:
#     541     if SparkContext._active_spark_context is None:
# --> 542         SparkContext(conf=conf or SparkConf())
#     543     assert SparkContext._active_spark_context is not None
#     544     return SparkContext._active_spark_context
#
# File c:\Users\ferch\OneDrive\Escritorio\ICAI\QUINTO\2_BIGDATA\PROYECTO\XRP\Lib\site-packages\pyspark\core\context.py:206, in SparkContext.__init__(self, master, appName, sparkHome, pyFiles, environment, batchSize, serializer, conf, gateway, jsc, profiler_cls, udf_profiler_cls, memory_profiler_cls)
#     200 if gateway is not None and gateway.gateway_parameters.auth_token is None:
#     201     raise ValueError(
#     202         "You are trying to pass an insecure Py4j gateway to Spark. This"
#     203         " is not allowed as it is a security risk."
#     204     )
# --> 206 SparkContext._ensure_initialized(self, gateway=gateway, conf=conf)
#     207 try:
#     208     self._do_init(
#     209         master,
#     210         appName,
#    (...)    220         memory_profiler_cls,
#     221     )
#
# File c:\Users\ferch\OneDrive\Escritorio\ICAI\QUINTO\2_BIGDATA\PROYECTO\XRP\Lib\site-packages\pyspark\core\context.py:463, in SparkContext._ensure_initialized(cls, instance, gateway, conf)
#     461 with SparkContext._lock:
#     462     if not SparkContext._gateway:
# --> 463         SparkContext._gateway = gateway or launch_gateway(conf)
#     464         SparkContext._jvm = SparkContext._gateway.jvm
#     466     if instance:
#
# File c:\Users\ferch\OneDrive\Escritorio\ICAI\QUINTO\2_BIGDATA\PROYECTO\XRP\Lib\site-packages\pyspark\java_gateway.py:111, in launch_gateway(conf, popen_kwargs)
#     108     time.sleep(0.1)
#     110 if not os.path.isfile(conn_info_file):
# --> 111     raise PySparkRuntimeError(
#     112         errorClass="JAVA_GATEWAY_EXITED",
#     113         messageParameters={},
#     114     )
#     116 with open(conn_info_file, "rb") as info:
#     117     gateway_port = read_int(info)
#
# PySparkRuntimeError: [JAVA_GATEWAY_EXITED] Java gateway process exited before sending its port number.

# %%
# Ejemplo de creación de un DataFrame a partir de los datos almacenados en HDFS
df = spark.read \
          .option("header","true") \
          .option("inferSchema", "true") \
          .csv("\data")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Ejemplo de creación de un DataFrame a partir de los datos almacenados en HDFS
# ----> 2 df = spark.read \
#       3           .option("header","true") \
#       4           .option("inferSchema", "true") \
#       5           .csv("\data")
#
# NameError: name 'spark' is not defined

# %%
df.printSchema()
# Out:
# root
#  |-- datetime: timestamp (nullable = true)
#  |-- open: double (nullable = true)
#  |-- high: double (nullable = true)
#  |-- low: double (nullable = true)
#  |-- close: double (nullable = true)
#  |-- volume: double (nullable = true)

# %%
df.show()
# Out:
# +-------------------+--------+---------+--------+---------+----------+
# |           datetime|    open|     high|     low|    close|    volume|
# +-------------------+--------+---------+--------+---------+----------+
# |2023-02-03 01:00:00|97852.49|102694.65|91274.44|101579.71|1046.90338|
# |2023-02-04 01:00:00|101594.8|101918.55|96210.61|101579.71|1046.90338|
# |2023-02-05 01:00:00|97991.51| 99216.89|96231.57|101579.71|1046.90338|
# |2023-02-06 01:00:00|96677.48| 99237.66|95769.99|101579.71|1046.90338|
# |2023-02-07 01:00:00|96637.26|100216.31|95687.47|101579.71|1046.90338|
# |2023-02-08 01:00:00|96629.36| 97024.68|95892.71|101579.71|1046.90338|
# |2023-02-09 01:00:00|96654.33| 97480.95|94827.29|101579.71|1046.90338|
# |2023-02-10 01:00:00|96538.82| 98393.28| 95335.2|101579.71|1046.90338|
# |2023-02-11 01:00:00|97468.48| 98507.72|94903.26|101579.71|1046.90338|
# |2023-02-12 01:00:00|95830.29| 96521.78|95142.15|101579.71|1046.90338|
# |2024-02-03 01:00:00|97852.49|102694.65|91274.44|101579.71|1046.90338|
# |2024-02-04 01:00:00|101594.8|101918.55|96210.61|101579.71|1046.90338|
# |2024-02-05 01:00:00|97991.51| 99216.89|96231.57|101579.71|1046.90338|
# |2024-02-06 01:00:00|96677.48| 99237.66|95769.99|101579.71|1046.90338|
# |2024-02-07 01:00:00|96637.26|100216.31|95687.47|101579.71|1046.90338|
# |2024-02-08 01:00:00|96629.36| 97024.68|95892.71|101579.71|1046.90338|
# |2024-02-09 01:00:00|96654.33| 97480.95|94827.29|101579.71|1046.90338|
# |2024-02-10 01:00:00|96538.82| 98393.28| 95335.2|101579.71|1046.90338|
# |2024-02-11 01:00:00|97468.48| 98507.72|94903.26|101579.71|1046.90338|
# |2024-02-12 01:00:00|95830.29| 96521.78|95142.15|101579.71|1046.90338|
# +-------------------+--------+---------+--------+---------+----------+
# only showing top 20 rows

# %%
df.count()
# Out:
# 30
